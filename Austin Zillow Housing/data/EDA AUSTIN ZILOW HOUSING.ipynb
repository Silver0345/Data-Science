# %% [markdown]
# ## Austin Zilow Housing Performance Indicator

# %% [markdown]
# #### Life cycle of Machine learning Project
#
# - Understanding the Problem Statement
# - Data Collection
# - Data Checks to perform
# - Exploratory data analysis
# - Data Pre-Processing
# - Model Training
# - Choose best model

# %% [markdown]
# ### 1) Problem statement
# - This project understands how the austin zilow housing's performance (price) is affected by other variables such as beds, baths, area, longitude and latitude.
#
#
# ### 2) Data Collection
# - Dataset Source -
#
# - The data consists of 8 column and 1000 rows.

# %% [markdown]
# ### 2.1 Import Data and Required Packages
# ####  Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv("../Zillow_Austin_11-16-22.csv")

# %% [markdown]
# ### Show Top 5 Records

# %%
df.head()
# Out:
#      price  unformattedPrice  \
# 0   445000            445000
# 1  1995000           1995000
# 2   929900            929900
# 3  6495000           6495000
# 4   365000            365000
#
#                                             address  \
# 0  8916 Mountain Shadows Cv APT B, Austin, TX 78735
# 1                  1701 Alguno Rd, Austin, TX 78757
# 2                 1800 Kinney Ave, Austin, TX 78704
# 3               2407 Pemberton Pl, Austin, TX 78703
# 4              11701 Lansdowne Rd, Austin, TX 78754
#
#                     addressStreet addressCity addressState  addressZipcode  \
# 0  8916 Mountain Shadows Cv APT B      Austin           TX           78735
# 1                  1701 Alguno Rd      Austin           TX           78757
# 2                 1800 Kinney Ave      Austin           TX           78704
# 3               2407 Pemberton Pl      Austin           TX           78703
# 4              11701 Lansdowne Rd      Austin           TX           78754
#
#    beds  baths    area   latitude  longitude  isZillowOwned  \
# 0   3.0    3.0  1802.0  30.269207  -97.86206          False
# 1   4.0    4.0  3443.0  30.333755  -97.73414          False
# 2   2.0    2.0  1318.0  30.252070  -97.76860          False
# 3   5.0    6.0  5000.0  30.290514  -97.75361          False
# 4   4.0    2.0  2127.0  30.355240  -97.61292          False
#
#                                         variableData  badgeInfo    pgapt  \
# 0  {'type': 'PRICE_REDUCTION', 'text': '$20,000 (...        NaN  ForSale
# 1   {'type': 'DAYS_ON', 'text': '19 days on Zillow'}        NaN  ForSale
# 2  {'type': 'OPEN_HOUSE', 'text': 'Open: Sat. 2-4...        NaN  ForSale
# 3  {'type': 'PRICE_REDUCTION', 'text': '$500,000 ...        NaN  ForSale
# 4             {'type': '3D_HOME', 'text': '3D Tour'}        NaN  ForSale
#
#                sgapt  zestimate  \
# 0  For Sale (Broker)    1189900
# 1   New Construction    2154600
# 2  For Sale (Broker)    1048700
# 3  For Sale (Broker)    6553400
# 4  For Sale (Broker)     421000
#
#                                          info3String  \
# 0  https://photos.zillowstatic.com/fp/98ab7c7b289...
# 1  https://photos.zillowstatic.com/fp/98ab7c7b289...
# 2  https://photos.zillowstatic.com/fp/98ab7c7b289...
# 3  https://photos.zillowstatic.com/fp/98ab7c7b289...
# 4  https://photos.zillowstatic.com/fp/98ab7c7b289...
#
#                     brokerName
# 0                Realty Austin
# 1           Jimmy Gilmore & Co
# 2       Keller Williams Realty
# 3  Douglas Elliman Real Estate
# 4            Orchard Brokerage

# %% [markdown]
# ### Shape of the dataset

# %%
df.shape
# Out:
# (800, 20)

# %% [markdown]
# ### 2.2 Dataset information
#
# - price
# - unformattedPrice
# - address
# - addressStreet
# - addressCity
# - addressState
# - addressZipcode
# - beds
# - baths
# - area
# - latitude
# - longitude
# - isZillowOwned
# - variableData
# - badgeInfo
# - pgapt
# - sgapt
# - zestimate
# - info3String
# - brokerNam

# %% [markdown]
# ### 3. Data Checks to perform
#
# - Check Missing values
# - Check Duplicates
# - Check data type
# - Check the number of unique values of each column
# - Check statistics of data set
# - Check various categories present in the different categorical column

# %% [markdown]
# ### 3.1 Check Missing Values

# %%
df.isna().sum()
# Out:
# price                 0
# unformattedPrice      0
# address               0
# addressStreet         0
# addressCity           0
# addressState          0
# addressZipcode        0
# beds                 15
# baths                 1
# area                  4
# latitude             14
# longitude            14
# isZillowOwned         0
# variableData          0
# badgeInfo           800
# pgapt                 0
# sgapt                 0
# zestimate             0
# info3String          40
# brokerName            8
# dtype: int64

# %% [markdown]
# ### 3.2 Check Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### There are no duplicates values in the dataset

# %% [markdown]
# ### 3.3 Check data types

# %%
# Check Null and dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             800 non-null    int64
#  1   unformattedPrice  800 non-null    int64
#  2   address           800 non-null    object
#  3   addressStreet     800 non-null    object
#  4   addressCity       800 non-null    object
#  5   addressState      800 non-null    object
#  6   addressZipcode    800 non-null    int64
#  7   beds              785 non-null    float64
#  8   baths             799 non-null    float64
#  9   area              796 non-null    float64
#  10  latitude          786 non-null    float64
#  11  longitude         786 non-null    float64
#  12  isZillowOwned     800 non-null    bool
#  13  variableData      800 non-null    object
#  14  badgeInfo         0 non-null      float64
#  15  pgapt             800 non-null    object
#  16  sgapt             800 non-null    object
#  17  zestimate         800 non-null    int64
#  18  info3String       760 non-null    object
#  19  brokerName        792 non-null    object
# dtypes: bool(1), float64(6), int64(4), object(9)
# memory usage: 119.7+ KB

# %% [markdown]
# ### 3.4 Checking the number of unique values of each column

# %%
df.nunique()
# Out:
# price               419
# unformattedPrice    419
# address             800
# addressStreet       800
# addressCity           6
# addressState          1
# addressZipcode       44
# beds                  8
# baths                11
# area                675
# latitude            768
# longitude           767
# isZillowOwned         1
# variableData        371
# badgeInfo             0
# pgapt                 1
# sgapt                 2
# zestimate           208
# info3String           2
# brokerName          253
# dtype: int64

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 11 numerical features : ['price', 'unformattedPrice', 'addressZipcode', 'beds', 'baths', 'area', 'latitude', 'longitude', 'isZillowOwned', 'badgeInfo', 'zestimate']
#
# We have 9 categorical features : ['address', 'addressStreet', 'addressCity', 'addressState', 'variableData', 'pgapt', 'sgapt', 'info3String', 'brokerName']

# %% [markdown]
# ### Dealinng With The Missing Value

# %%
housing = df


housing.head(3)
# Out:
#      price  unformattedPrice  \
# 0   445000            445000
# 1  1995000           1995000
# 2   929900            929900
#
#                                             address  \
# 0  8916 Mountain Shadows Cv APT B, Austin, TX 78735
# 1                  1701 Alguno Rd, Austin, TX 78757
# 2                 1800 Kinney Ave, Austin, TX 78704
#
#                     addressStreet addressCity addressState  addressZipcode  \
# 0  8916 Mountain Shadows Cv APT B      Austin           TX           78735
# 1                  1701 Alguno Rd      Austin           TX           78757
# 2                 1800 Kinney Ave      Austin           TX           78704
#
#    beds  baths    area   latitude  longitude  isZillowOwned  \
# 0   3.0    3.0  1802.0  30.269207  -97.86206          False
# 1   4.0    4.0  3443.0  30.333755  -97.73414          False
# 2   2.0    2.0  1318.0  30.252070  -97.76860          False
#
#                                         variableData  badgeInfo    pgapt  \
# 0  {'type': 'PRICE_REDUCTION', 'text': '$20,000 (...        NaN  ForSale
# 1   {'type': 'DAYS_ON', 'text': '19 days on Zillow'}        NaN  ForSale
# 2  {'type': 'OPEN_HOUSE', 'text': 'Open: Sat. 2-4...        NaN  ForSale
#
#                sgapt  zestimate  \
# 0  For Sale (Broker)    1189900
# 1   New Construction    2154600
# 2  For Sale (Broker)    1048700
#
#                                          info3String              brokerName
# 0  https://photos.zillowstatic.com/fp/98ab7c7b289...           Realty Austin
# 1  https://photos.zillowstatic.com/fp/98ab7c7b289...      Jimmy Gilmore & Co
# 2  https://photos.zillowstatic.com/fp/98ab7c7b289...  Keller Williams Realty

# %% [markdown]
# ### Dealing With The Missing Values
# - By dropping 'badgeInfo' column because it has no values
# - By filling the missing categorical values with their modes
# - By filling the numcial missing values with the means

# %%
[housing[cat] == housing[cat].fillna(housing[cat].mode()[0],inplace=True) for cat in categorical_features  ]
[housing[num] == housing[num].fillna(housing[num].mean(),inplace=True) for num in numeric_features  ]
housing = housing.drop(['badgeInfo'], axis=1)
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             800 non-null    int64
#  1   unformattedPrice  800 non-null    int64
#  2   address           800 non-null    object
#  3   addressStreet     800 non-null    object
#  4   addressCity       800 non-null    object
#  5   addressState      800 non-null    object
#  6   addressZipcode    800 non-null    int64
#  7   beds              800 non-null    float64
#  8   baths             800 non-null    float64
#  9   area              800 non-null    float64
#  10  latitude          800 non-null    float64
#  11  longitude         800 non-null    float64
#  12  isZillowOwned     800 non-null    bool
#  13  variableData      800 non-null    object
#  14  pgapt             800 non-null    object
#  15  sgapt             800 non-null    object
#  16  zestimate         800 non-null    int64
#  17  info3String       800 non-null    object
#  18  brokerName        800 non-null    object
# dtypes: bool(1), float64(5), int64(4), object(9)
# memory usage: 113.4+ KB

# %% [markdown]
# ### 3.5 Check statistics of data set

# %%
housing.describe()
# Out:
#               price  unformattedPrice  addressZipcode        beds       baths  \
# count  8.000000e+02      8.000000e+02       800.00000  800.000000  800.000000
# mean   9.696823e+05      9.696823e+05     78734.11500    3.331210    2.675845
# std    1.478447e+06      1.478447e+06        21.51576    0.967485    1.214763
# min    9.990000e+04      9.990000e+04     78617.00000    0.000000    0.000000
# 25%    4.247500e+05      4.247500e+05     78724.00000    3.000000    2.000000
# 50%    5.899500e+05      5.899500e+05     78739.00000    3.000000    2.000000
# 75%    8.193750e+05      8.193750e+05     78748.00000    4.000000    3.000000
# max    1.800000e+07      1.800000e+07     78759.00000    7.000000   10.000000
#
#                area    latitude   longitude     zestimate
# count    800.000000  800.000000  800.000000  8.000000e+02
# mean    2142.964824   30.293275  -97.764621  1.815941e+05
# std     1314.008167    0.091419    0.079827  5.112124e+05
# min      391.000000   30.103233  -98.019940  0.000000e+00
# 25%     1387.750000   30.218595  -97.810585  0.000000e+00
# 50%     1843.000000   30.288638  -97.757890  0.000000e+00
# 75%     2490.250000   30.363522  -97.716499  2.931110e+05
# max    14025.000000   30.516008  -97.570600  6.553400e+06

# %% [markdown]
# ### Insight
#
# -

# %% [markdown]
# ### 3.7 Exploring The Data

# %%
housing.head()
# Out:
#      price  unformattedPrice  \
# 0   445000            445000
# 1  1995000           1995000
# 2   929900            929900
# 3  6495000           6495000
# 4   365000            365000
#
#                                             address  \
# 0  8916 Mountain Shadows Cv APT B, Austin, TX 78735
# 1                  1701 Alguno Rd, Austin, TX 78757
# 2                 1800 Kinney Ave, Austin, TX 78704
# 3               2407 Pemberton Pl, Austin, TX 78703
# 4              11701 Lansdowne Rd, Austin, TX 78754
#
#                     addressStreet addressCity addressState  addressZipcode  \
# 0  8916 Mountain Shadows Cv APT B      Austin           TX           78735
# 1                  1701 Alguno Rd      Austin           TX           78757
# 2                 1800 Kinney Ave      Austin           TX           78704
# 3               2407 Pemberton Pl      Austin           TX           78703
# 4              11701 Lansdowne Rd      Austin           TX           78754
#
#    beds  baths    area   latitude  longitude  isZillowOwned  \
# 0   3.0    3.0  1802.0  30.269207  -97.86206          False
# 1   4.0    4.0  3443.0  30.333755  -97.73414          False
# 2   2.0    2.0  1318.0  30.252070  -97.76860          False
# 3   5.0    6.0  5000.0  30.290514  -97.75361          False
# 4   4.0    2.0  2127.0  30.355240  -97.61292          False
#
#                                         variableData    pgapt  \
# 0  {'type': 'PRICE_REDUCTION', 'text': '$20,000 (...  ForSale
# 1   {'type': 'DAYS_ON', 'text': '19 days on Zillow'}  ForSale
# 2  {'type': 'OPEN_HOUSE', 'text': 'Open: Sat. 2-4...  ForSale
# 3  {'type': 'PRICE_REDUCTION', 'text': '$500,000 ...  ForSale
# 4             {'type': '3D_HOME', 'text': '3D Tour'}  ForSale
#
#                sgapt  zestimate  \
# 0  For Sale (Broker)    1189900
# 1   New Construction    2154600
# 2  For Sale (Broker)    1048700
# 3  For Sale (Broker)    6553400
# 4  For Sale (Broker)     421000
#
#                                          info3String  \
# 0  https://photos.zillowstatic.com/fp/98ab7c7b289...
# 1  https://photos.zillowstatic.com/fp/98ab7c7b289...
# 2  https://photos.zillowstatic.com/fp/98ab7c7b289...
# 3  https://photos.zillowstatic.com/fp/98ab7c7b289...
# 4  https://photos.zillowstatic.com/fp/98ab7c7b289...
#
#                     brokerName
# 0                Realty Austin
# 1           Jimmy Gilmore & Co
# 2       Keller Williams Realty
# 3  Douglas Elliman Real Estate
# 4            Orchard Brokerage

# %%
housing.hist(bins=25, figsize=(12,7));

# %%
housing = housing.drop(['unformattedPrice'], axis=1)
data_corr = housing.corr()

plt.figure(figsize=(14,8))
sns.heatmap(data_corr, annot=True)
# Out:
# <AxesSubplot: >

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(x='beds', data=housing,kde=True,hue='beds')
plt.subplot(142)
sns.histplot(x='baths',data=housing,kde=True,hue='baths')
plt.subplot(143)
sns.histplot(x='area',data=housing,kde=True)
plt.show()

# %%
beds = pd.DataFrame(housing['beds'].sort_values(ascending = False))
price = pd.DataFrame(housing['price'].sort_values(ascending = False))
bed_price = beds.join(price)
bed_price.head()
# Out:
#      beds    price
# 772   7.0  3900000
# 138   7.0   499000
# 202   6.0  2995000
# 185   6.0   999999
# 118   6.0   595000

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='beds', x='price', data= bed_price[:30])
plt.xticks(rotation=90)
plt.title(' Top 30 Number of Bedrooms Vs Price');

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='beds', x='price', data= bed_price[-30:])
plt.xticks(rotation=90)
plt.title(' Bottom 30 Number of Bedrooms Vs Price');

# %%
area = pd.DataFrame(housing['area'].sort_values(ascending = False))
price = pd.DataFrame(housing['price'].sort_values(ascending = False))
area_price = area.join(price)
area_price.head()
# Out:
#         area     price
# 799  14025.0  18000000
# 311  13037.0   5200000
# 788  10637.0   6499000
# 772  10306.0   3900000
# 798   8549.0  13500000

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='area', x='price', data= area_price[:30])
plt.xticks(rotation=90)
plt.title(' Top 30 Areas Vs Price');

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='area', x='price', data= area_price[-30:])
plt.xticks(rotation=90)
plt.title('Bottom 30 Areas Vs Price');

# %%
baths = pd.DataFrame(housing['baths'].sort_values(ascending = False))
price = pd.DataFrame(housing['price'].sort_values(ascending = False))
bath_price = baths.join(price)
bath_price.head()
# Out:
#      baths    price
# 311   10.0  5200000
# 772    9.0  3900000
# 795    8.0  9990000
# 736    8.0  1775000
# 791    8.0  7499000

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='baths', x='price', data= bath_price[:30])
plt.xticks(rotation=90)
plt.title(' Top 30 Number of Baths Vs Price');

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='baths', x='price', data= bath_price[-30:])
plt.xticks(rotation=90)
plt.title('Bottom 30 Number of Baths Vs Price');

# %%
sns.pairplot(housing,hue='price')
plt.show();
